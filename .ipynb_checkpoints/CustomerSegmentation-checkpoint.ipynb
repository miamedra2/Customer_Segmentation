# %%
import pandas as pd
import numpy as np
import sqlite3
import functools as fn
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer 
import seaborn as sns

# %%
ls
# Out:
# 1550201769_PBL 5 recommendation data (1).csv
# CustomerSegmentation.ipynb
# Untitled.ipynb

# %%
df = pd.read_csv("1550201769_PBL 5 recommendation data (1).csv", encoding='latin-1')
# Out:
# /Users/michael/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (20,33,73,106,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Customers.id Customers.fname Customers.lname Customers.company  \
# 0           797         Christy            Dill          Company0
# 1             3            John           Smith          Company1
# 2             3            John           Smith          Company1
# 3             4           James        Anderson               NaN
# 4             5         Abraham          Pollak          Company3
#
#    Customers.create_date  Customers.status  Customers.mailing  \
# 0             1426018724               NaN                NaN
# 1             1386089139               NaN                NaN
# 2             1386089139               NaN                NaN
# 3             1386780263               NaN                NaN
# 4             1386861599               0.0                0.0
#
#    Customers.reminders  Customers.tax_exempt  Customers.account_id  ...  \
# 0                  NaN                   NaN                   NaN  ...
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4194 entries, 0 to 4193
# Data columns (total 181 columns):
# Customers.id                      int64
# Customers.fname                   object
# Customers.lname                   object
# Customers.company                 object
# Customers.create_date             int64
# Customers.status                  float64
# Customers.mailing                 float64
# Customers.reminders               float64
# Customers.tax_exempt              float64
# Customers.account_id              float64
# Customers.sales_rep               float64
# Customers.rewards                 float64
# Customers.profile_id              float64
# Customers.last_modified           int64
# Customers.customer_type           float64
# Orders.id                         int64
# Orders.customer_id                int64
# Orders.fname                      object
# Orders.lname                      object
# Orders.company                    object
# ...

# %%
customer_df = df
orders_df = df
orderitems_df = df
products_df = df

# %%
customer_df = customer_df.drop([elem for elem in df if elem[:8] != 'Customer'], axis=1)
products_df = products_df.drop([elem for elem in df if elem[:7] != 'Product'], axis=1)

# %%
orders_df = orders_df.drop([elem for elem in df if elem[:6] != 'Orders'], axis=1)
orderitems_df = orderitems_df.drop([elem for elem in df if elem[:11] != 'Order_Items'], axis=1)

# %%
def ParseDataFrameNames(df_in):
    try:
        newelem = [elem.split('.')[1] for elem in df_in]
        oldelem = [elem for elem in df_in]
        for i in range(len(newelem)):
            df_in[newelem[i]] = df_in[oldelem[i]]
    
        df_in.drop(oldelem, axis=1, inplace = True)
        return df_in
    except:
        return df_in

# %%
customer_df = ParseDataFrameNames(customer_df)
products_df = ParseDataFrameNames(products_df)
orders_df = ParseDataFrameNames(orders_df)
orderitems_df = ParseDataFrameNames(orderitems_df)

# %%
#cnx = sqlite3.connect(':memory:')

# %%
#customer_df.to_sql(name='customer_df', con=cnx)
#products_df.to_sql(name='products_df', con=cnx)
#orders_df.to_sql(name='orders_df', con=cnx)
#orderitems_df.to_sql(name='orderitems_df', con=cnx)

# %%
#customer_df = pd.read_sql('select * from customer_df', cnx)
#products_df = pd.read_sql('select * from products_df', cnx)
#orders_df = pd.read_sql('select * from orders_df', cnx)
#orderitems_df = pd.read_sql('select * from orderitems_df', cnx)

# %%
df_list = [customer_df, products_df, orders_df]

# %%
df = fn.reduce(lambda  left,right: pd.merge(left,right,on=['id']), df_list)

# %%
df.head()
# Out:
#    id  fname_x   lname_x  company_x  create_date  status_x  mailing_x  \
# 0  30   Jesse   Spalding        NaN   1392311828       NaN        NaN
# 1  30   Jesse   Spalding        NaN   1392311828       NaN        NaN
# 2  30   Jesse   Spalding        NaN   1392311828       NaN        NaN
# 3  74  Richard     Ernst  Company11   1395689831       NaN        NaN
# 4  76     Iddo    Enochs        NaN   1395763639       NaN        NaN
#
#    reminders  tax_exempt  account_id  ...  shipped_date  comments     notes_y  \
# 0        NaN         NaN         NaN  ...  1.386876e+09       NaN         NaN
# 1        NaN         NaN         NaN  ...  1.386876e+09       NaN         NaN
# 2        NaN         NaN         NaN  ...  1.386876e+09       NaN         NaN
# 3        NaN         NaN         NaN  ...  1.391709e+09       NaN  Ebay Order
# 4        NaN         NaN         NaN  ...  1.390839e+09       NaN         NaN
#
#    registry_id  gift_message  website  mailing_y flags_y  partial_ship  \
# ...

# %%
df.shape
# Out:
# (574, 164)

# %%
df1 = df.select_dtypes(exclude=['object'])
df2 = df.select_dtypes(include=['object'])

# %%
df1.shape
# Out:
# (574, 93)

# %%
df2.shape
# Out:
# (574, 71)

# %%
df1.head()
# Out:
#    id  create_date  status_x  mailing_x  reminders  tax_exempt  account_id  \
# 0  30   1392311828       NaN        NaN        NaN         NaN         NaN
# 1  30   1392311828       NaN        NaN        NaN         NaN         NaN
# 2  30   1392311828       NaN        NaN        NaN         NaN         NaN
# 3  74   1395689831       NaN        NaN        NaN         NaN         NaN
# 4  76   1395763639       NaN        NaN        NaN         NaN         NaN
#
#    sales_rep_x  rewards  profile_id  ...  placed_date  updated_date  \
# 0          NaN      NaN         NaN  ...   1386861599  1.440529e+09
# 1          NaN      NaN         NaN  ...   1386861599  1.440529e+09
# 2          NaN      NaN         NaN  ...   1386861599  1.440529e+09
# 3          NaN      NaN         NaN  ...   1390573155  1.440529e+09
# 4          NaN      NaN         NaN  ...   1390613419  1.440529e+09
#
#    shipped_date  registry_id  gift_message  website  mailing_y  flags_y  \
# ...

# %%
df2.head()
# Out:
#    fname_x   lname_x  company_x                 template  \
# 0   Jesse   Spalding        NaN  sub-product-detail.html
# 1   Jesse   Spalding        NaN  sub-product-detail.html
# 2   Jesse   Spalding        NaN  sub-product-detail.html
# 3  Richard     Ernst  Company11  sub-product-detail.html
# 4     Iddo    Enochs        NaN  sub-product-detail.html
#
#                                            name  \
# 0             Biomask Antiviral Face Masks,Blue
# 1             Biomask Antiviral Face Masks,Blue
# 2             Biomask Antiviral Face Masks,Blue
# 3  Smooth Bottom Shoe Covers,Blue,Regular/Large
# 4   Standard Polypropylene Non-Skid Shoe Covers
#
#                                      display_name shopping_brand shopping_mpn  \
# 0              Biomask Antiviral Face Masks, Blue        MEDLINE   BIOM2001AZ
# 1              Biomask Antiviral Face Masks, Blue        MEDLINE   BIOM2001AZ
# 2              Biomask Antiviral Face Masks, Blue        MEDLINE   BIOM2001AZ
# ...

# %%
def getelbowplot(df_in):

    Sum_of_squared_distances = []
    K = range(1,15)
    for k in K:
        km = KMeans(n_clusters=k)
        km = km.fit(df_in)
        Sum_of_squared_distances.append(km.inertia_)
        
    plt.plot(K, Sum_of_squared_distances, 'bx-')
    plt.xlabel('Number of Clusters')
    plt.ylabel('Distortion')
    plt.title('Elbow Plot')

# %%
droplist = []
for elem in df1:
    for cnt in range(len(df1[elem].unique())):
        if np.isnan(df1[elem].unique()[cnt]) == True and len(df1[elem].unique()) <=3 or len(df1[elem].unique()) <=1:
            droplist.append(elem)
        
df1 = df1.drop(droplist, axis = 1)

# %%
df1.shape
# Out:
# (574, 45)

# %%
df1 = df1.groupby('id').mean()

# %%
df1.shape
# Out:
# (151, 44)

# %%
df1.isnull().sum()
# Out:
# create_date           0
# last_modified_x       0
# customer_type_x      18
# status_y              0
# vendor                0
# import_id             0
# list_price            0
# price                 0
# sale_price          135
# cost                  0
# flags_x              23
# left_flag           125
# last_modified_y       0
# shopping_gtin        27
# amazon_price        147
# qb_edit_sequence      0
# length              110
# width               110
# height              110
# upc                  72
# case_qty             41
# import_flags         72
# map_price           146
# shipping_length       0
# shipping_width        0
# shipping_height       0
# shipping_weight     110
# customer_id           0
# subtotal              0
# tax                  52
# shipping              2
# coupon_id           131
# coupon_amount       131
# fee_amount          127
# discount_amount     120
# total                 0
# balance_due         126
# payment_status        0
# ...

# %%
df1 = df1.dropna(axis=1)

# %%
df1.shape
# Out:
# (151, 20)

# %%
for elem in df1:
    print(elem+str(':'), df1[elem].unique())
# Out:
# create_date: [1392311828 1395689831 1395763639 1396586169 1399310591 1401470254
#  1404847725 1405634541 1405801030 1406140854 1406216479 1406581818
#  1407771804 1409162533 1409773499 1410107008 1410358486 1410367179
#  1411394081 1412187493 1413904444 1413984421 1414003523 1414337958
#  1414429423 1414603114 1418240686 1419851558 1420056667 1420577811
#  1421167221 1425274376 1426535367 1426700708 1426711196 1426773944
#  1426777217 1427213316 1427425376 1427657242 1428876526 1429625013
#  1429631754 1429724567 1429910874 1430169842 1430177791 1430501895
#  1430503085 1431357047 1431573201 1432787003 1433793911 1433873617
#  1433964929 1434037116 1435260256 1435586379 1435603015 1435607495
#  1435785076 1436375878 1437878498 1438028848 1438264923 1439068796
#  1439216649 1439342025 1439484499 1439822001 1440350638 1440365983
#  1440435425 1440790040 1440859485 1440889323 1441041314 1441049334
#  1441053753 1441224293 1441818436 1442025321 1442077814 1443197790
# ...

# %%
getelbowplot(df1)

# %%
df1.head()
# Out:
#      create_date  last_modified_x  status_y  vendor  import_id  list_price  \
# id
# 30    1392311828       1437763560       0.0     1.0        3.0       53.61
# 74    1395689831       1437764445       0.0     1.0        3.0       34.73
# 76    1395763639       1437762888       0.0     1.0        3.0       21.07
# 105   1396586169       1437763353       0.0     1.0        3.0       38.61
# 123   1399310591       1437763098       0.0     1.0        3.0      588.00
#
#       price    cost  last_modified_y  qb_edit_sequence  shipping_length  \
# id
# 30    38.29   27.35     1.462370e+09      1.450321e+09            10.30
# 74    24.81   17.11     1.462370e+09      1.450322e+09            16.54
# 76    15.05    8.60     1.462370e+09      1.450322e+09             8.75
# 105   27.58   19.02     1.462370e+09      1.450322e+09            11.50
# 123  420.00  336.00     1.462370e+09      1.450322e+09            20.00
#
#      shipping_width  shipping_height  customer_id  subtotal  total  \
# ...

# %%
corr = df1.corr()

sns.heatmap(abs(corr),xticklabels=corr.columns, yticklabels=corr.columns)

# %%
for elem in df2:
    print(elem+str(':'), df2[elem].unique())
# Out:
# fname_x: ['Jesse ' 'Richard' 'Iddo' 'Ryan' 'Thomas' 'lauren ' 'James' 'Sheila'
#  'Kathleen' 'Kevin' 'GREG' 'Lester ' 'Gloria' 'Dorothy' 'Kim' 'Pam '
#  'Susan ' 'mary' 'charles ' 'Natalie' 'lisa' 'Janick ' 'Mary' 'Helen'
#  'Barbara' 'Patricia' 'Larry' 'Haijuan' 'J.A.' 'Travestean' 'Jeaneen'
#  'larry' 'Jesus' 'Vivian' 'Mirjana' 'Michelle' 'Deborah' 'Brenda' 'Lynda'
#  'Daryl' 'Cathy' 'Sally' 'Ruth' 'TARI L.' 'billie' 'I' 'Betty ' 'Karen'
#  'jearlean' 'Lou ' 'Curtis' 'Janet' 'Martha' 'Vilene' 'Charlene' 'Santosh'
#  'Maria Tereca' 'Shawniece' 'Katherine ' 'Barney' 'William' 'Bill '
#  'Dennis' 'Raymond' 'Donna' 'Kelli' 'Katalin' 'Rebecca' 'Robert' 'Krisila'
#  'PJ' 'Anthony' 'Amanda' 'Elaine' 'Margaret' 'Annette' 'Jennifer' 'Leslie'
#  'patricia' 'Brian' 'Maureen' 'Lorraine' 'John' 'KEN' 'Dorthy' 'Sam'
#  'Alice ' 'Albino' 'Tzu Lu' 'Sandy' 'Frances Clark' 'Jane' 'Elaina'
#  'Carla' 'Amy' 'Roy' 'Linda' 'A' 'Laura' 'David' 'william ' 'jean'
# ...

# %%
df2.shape
# Out:
# (574, 71)

# %%
df2.isnull().sum()
# Out:
# fname_x             0
# lname_x             0
# company_x         535
# template            0
# name                0
#                  ...
# payment_method    358
# payment_id        193
# payment_code      223
# comments          537
# notes_y           165
# Length: 71, dtype: int64

# %%
df2 = df2.dropna(axis=1)

# %%
df2.shape
# Out:
# (574, 20)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 574 entries, 0 to 573
# Data columns (total 20 columns):
# fname_x                 574 non-null object
# lname_x                 574 non-null object
# template                574 non-null object
# name                    574 non-null object
# display_name            574 non-null object
# shopping_brand          574 non-null object
# shopping_mpn            574 non-null object
# amazon_item_type        574 non-null object
# google_shopping_type    574 non-null object
# google_shopping_cat     574 non-null object
# quickbooks_id           574 non-null object
# long_description        574 non-null object
# seo_title               574 non-null object
# seo_url                 574 non-null object
# unit                    574 non-null object
# family_id               574 non-null object
# fname_y                 574 non-null object
# lname_y                 574 non-null object
# order_number            574 non-null object
# ...

# %%
for elem in df2:
    print(elem+str(':'),df2[elem].unique())
# Out:
# fname_x: ['Jesse ' 'Richard' 'Iddo' 'Ryan' 'Thomas' 'lauren ' 'James' 'Sheila'
#  'Kathleen' 'Kevin' 'GREG' 'Lester ' 'Gloria' 'Dorothy' 'Kim' 'Pam '
#  'Susan ' 'mary' 'charles ' 'Natalie' 'lisa' 'Janick ' 'Mary' 'Helen'
#  'Barbara' 'Patricia' 'Larry' 'Haijuan' 'J.A.' 'Travestean' 'Jeaneen'
#  'larry' 'Jesus' 'Vivian' 'Mirjana' 'Michelle' 'Deborah' 'Brenda' 'Lynda'
#  'Daryl' 'Cathy' 'Sally' 'Ruth' 'TARI L.' 'billie' 'I' 'Betty ' 'Karen'
#  'jearlean' 'Lou ' 'Curtis' 'Janet' 'Martha' 'Vilene' 'Charlene' 'Santosh'
#  'Maria Tereca' 'Shawniece' 'Katherine ' 'Barney' 'William' 'Bill '
#  'Dennis' 'Raymond' 'Donna' 'Kelli' 'Katalin' 'Rebecca' 'Robert' 'Krisila'
#  'PJ' 'Anthony' 'Amanda' 'Elaine' 'Margaret' 'Annette' 'Jennifer' 'Leslie'
#  'patricia' 'Brian' 'Maureen' 'Lorraine' 'John' 'KEN' 'Dorthy' 'Sam'
#  'Alice ' 'Albino' 'Tzu Lu' 'Sandy' 'Frances Clark' 'Jane' 'Elaina'
#  'Carla' 'Amy' 'Roy' 'Linda' 'A' 'Laura' 'David' 'william ' 'jean'
# ...

# %%
droplist = ['fname_x', 'lname_x', 'display_name', 'fname_y', 'lname_y', 'currency', 'template', 'display_name', 'amazon_item_type', 'long_description']
df2 = df2.drop(droplist, axis=1)
df2 = pd.get_dummies(df2)
